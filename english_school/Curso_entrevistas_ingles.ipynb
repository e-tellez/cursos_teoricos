# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1>What am I gonna get in this course?</h1>
# </div>
#
# <ol>
#     <li>Learn how to prepare for a job interview.</li>
#     <li>The most common types of interviews you may face.</li>
#     <li>Be more prepared to answer interview questions.</li>
#     <li>To identify best practices you can apply during interviews.</li>
#     <li>We'll review some of the most common mistakes during interviews</li>
# </ol>
#
# <h2>Please complete each task/activities! <br> It will be very usefull.</h2>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h1>General Resources.</h1>
# </div>
#
# Here you can check some examples: [Recursos para entrevistas de trabajo en inglés.](https://drive.google.com/drive/folders/1wHHgjYgYpD0n0hRLhZQdudE4akEHEMRE?usp=sharing)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1>Preparing ourselves for the interview.</h1>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h1 style style="text-align:center">Vocabulary.</h1>
# </div>
#
# <b>Cover letter:</b> 1 page document that you should send with your resume to persuade the hiring manager to read it.
#
# <b>Complimentary closing:</b> a word or words that come immediately before the signature of a letter to express the sender’s respect for the recipient. For example: Sincerely or Regards.
#
# <b>Professional experience:</b> a experience that you obtain from a profession. It should be included in your resume in order from current to previous.
#
# <b>Hiring manager:</b> the person responsible for hiring employees, to fill open job positions in a company.
#
# <b>LinkedIn:</b> a social networking site that helps you create professional connections according to common areas and interests, as well as you find job opportunities.
#
# <b>Professional Profile:</b> it is a brief summary of your skills, qualifications, strengths, and relevant professional experience.
#
# <b>Resume or Resumé:</b> a formal presentation in a 1 or 2 page document, in which a job applicant showcases his or her contact information, professional summary, relevant work experience, education, skills and qualifications.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>How to improve my english?</h1>
# </div>
#
# The particular skills in english can be detached in:
#
# <ol>
#     <li>Speaking</li>
#     <li>Reading</li>
#     <li>Writing</li>
#     <li>Listening</li>
# </ol>
#
# So now you can focus doing different things with each skill you want to work on. It's highly recommended that you look for someone else that also wants to improve their skills, so you can work together!
#
# Keep in mind what motivates you to learn, mistakes are totally normal, learn from it.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>What should your resume include?</h1>
# </div>
# <ol>
#     <h3><li>Personal information and contact details.</li><h3>
#         <ul>
#             <h3><li>(LinkedIn and GitHub)</li></h3>
#         </ul>
#     <h3><li>Profesional summary.</li><h3>
#         <ul>
#             <h3><li>Experiencie and skills</li></h3>
#         </ul>
#     <h3><li>Relevant experience (current job first).</li><h3>
#         <ul>
#             <h4><li>Position</li></h4>
#             <h4><li>Company</li></h4>
#             <h4><li>Responsabilities</li></h4>
#             <h4><li>Achivements</li></h4>
#         </ul>
#     <h3><li>Education.</li></h3>
#         <ul>
#             <li><i>Start with your latest education.</i></li>
#         </ul>
#     <h3><li>Skills (soft and hard).</li></h3>
#             <ul>
#                 <li><i>Soft are prefered.</i></li>
#             </ul>
#     <h3><li>Languages - Level.</li></h3>
# </ol>
#
# ## Adition:
# > ### - Certifications.
# > ### - Awards.
# > ### - Volunteering work.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2><b>Use:</b></h2>
# </div>
# <ul>
#     <li><h3>Choose a legible font such as Arial or Tahoma.</h3></li>
#     <li><h3>Double-check spelling and punctuation.</h3></li>
#     <li><h3>Resume should be 1 or 2 pages max.</h3></li>
# <li><h3>Don't include a photo unless you are asked to in the job posting.</h3></li>
#     <li><h3>Send it in PDF.</h3></li>
# </ul>

# %% [markdown]
# <b>Resources:</b>
# > - [Grammarly](https://www.grammarly.com)
# > - [15 frases para entrevistas de trabajo en inglés](https://platzi.com/blog/frases-entrevistas-trabajo-ingles/)
# > - [Most powerful words to use during your interview](https://www.thebalancecareers.com/powerful-words-for-job-interviews-4123781)
# > - [Useful phrases for a job interview - EF](https://www.ef.com/wwen/blog/language/useful-phrases-for-a-job-interview/)
# > - [List of positive adjetives when you apply for jobs - ESOL](https://www.esolcourses.com/content/englishforwork/jobvocab/job-interview-positive-personality-adjectives.html)
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center"><b>Cover letter</b></h2>
# </div>
#
# ### Half of recruiters won't look at your resume if it don't have a cover letter attached to it.
#
# ### A cover letter it's a 1 page document that persuades the hiring manager to read it.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h3><b>Include:</b></h3>
# </div>
# <ul>
#     <li><h4>Your personal information, contact details and date when you're sending the letter.</h4></li>
#     <li><h4>Recipient's name and address, also maybe the title and company name.</h4></li>
#     <li><h4>Profesional greeting.</h4></li>
#     <li><h4>Opening paragraph, including your top skills.</h4></li>
#     <li><h4>Include why you are the right person for the job and why the company is right for you.</h4></li>
#     <li><h4>Conclusion with a call to action. Like:</h4>
#         <ul>
#             <b>'I look forward to discussing any particular job openings at your company.'</b>
#         </ul></li>
#     <li><h4>Complimentary closing and your signature.</h4></li>
# </ul>
#
# <br>
#
# > - You can consult in _General resources_ the example of a cover letter I've attached for you.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center"><b>LinkedIn</b></h1>
# </div>
# <ol>
#     <h2><li>Have a profesional profile photo and using a cover photo that has to do with your field.</li></h2>
#     <h2><li>Having a descriptive but short headline</li></h2>
#     <h2><li>Including your professional summary. Skills or strenghts as a list or  points.</li></h2>
#     <h2><li>Highlighting projects and content you have created.</li></h2>
#     <h2><li>Select your strongest skills. The ones which you want to work on.</li></h2>
#     <h2><li>Expand your network and be present.</li></h2>
#         <ul>
#             <h3><li>Friends, bosses, colleages.</li></h3>
#             <h3><li>Congratulate your contacts, for promotion and birthdays.</li></h3>
#         </ul>
#     <h2><li>Share relevant content. Creation of blogs, relevant content in news feed.</li></h2>
#     <h2><li>Have a persionalized URL with your name and last name.</li></h2>
# </ol>
#
# ## Adition:
# > ### - Certifications.
# > ### - Personal proyects.
#
# ## Resources:
# <ul>
#     <li><h3><a href="https://business.linkedin.com/en-uk/marketing-solutions/blog/posts/content-marketing/2017/17-steps-to-a-better-LinkedIn-profile-in-2017">20 steps to a better LinkedIn profile</a><h3></li>
# </ul>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2 style style="text-align:center"><b>How to prepare for the interview.</b></h2>
# </div>
#
# - **Research about the company.**
# > - Website. Their values, mision.
# > - Social media
# > - News.
#
# - **Review job description.**
# > - Requirements
# > - Skills
# > - Responsabilities
# This will help you to think about your answers to posible or common questions.
#
# - Check the interviewer's profile.
#
# - **Anticipate possible questions and practice answering questions.**
#
# - **Write down any questions that you might have for the interviewer.**
# > - Things that you would like to know.
#
# - **Sleep well the night before the interview.**
#
# ----

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1 style style="text-align:center">Types of interviews.</h1>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2 style style="text-align:center">Vocabulary.</h2>
# </div>
#
# <b>Advantages:</b> features that make something better than other things, and a condition that is more favorable and could give more possibilities to have a positive experience and success.
#
# <b>Disadvantages:</b> the opposite of advantages; a disadvantage is an unfavorable position or condition.
#
# <b>Face to face Interview:</b> an interview in which you talk directly to your interviewer in the same place, not by phone or online.
#
# <b>Online Interview:</b> an interview in which the interviewer and interviewee connect through an online platform.
#
# <b>Phone Interview:</b> an interview which is done over the phone..
#
# <b>Requirements:</b> something that is wanted or needed, it could also be a necessary condition.
#
# <b>Soft solid colors:</b> a color that has muted chroma, that was greyed, softened, or lightened, which has no patterns; a solid color is having the same color all over.
#
# <b>Technical Interview:</b> an interview to test technical abilities and knowledge for a job. Usually if you apply for a job in engineering, science, or IT you may face a technical interview.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1><b>What should i consider in face to face interview?</b></h1>
# </div>
#
# ### Advantages:
#
# > - **You save time and money.**
# > - **You don't have to go to the interview venue.**
# > - **You might feel more confortable.**
# > - **You can be at home or some place you already know.**
# > - **You can have more interviews with international companies.**
#
#
# ### Disadvantages:
#
# > - **They are more impersonal than face to face interviews**
# > - **There could be some issues regarding the internet speed.**
# > - **You might not have enough time to expand your answers.**
# > > Like in a face to face interview, that it's more like a conversation.
# > - **If it's a phone interview you could:**
# >> - Have issues with the call.
# >> - Incomings calls and messages (that could distract you).

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2><b>Tools for online interviews.</b></h2>
# </div>
#
# > <ol>
#     <li> A laptop or desktop computer.</li>
#     <li> Webcam.</li>
#     <li> Headphones with a built-in microphone.</li>
#     <li> Good internet conection. It's highly recommended that you have at least 5 Mps.</li>
# </ol>
#
#
# <div class="alert alert-block alert-info">
#     <h2 style="text-align:center"><b>Tips.</b></h2>
# </div>
#
# <ul>
#     <li><b> Make sure you have the link for the interview.</b></li>
#     <li> Sit in a quiet place, you'll need:
#         <ol>
#             <li> Privacy.</li>
#             <li> No external noises.</li>
#             <li> Good lighting.</li>
#         </ol>
#     </li>
#     <li> Connect to the internet using a cable. (It's more stable)</li>
#     <li> Test your audio and video settings.</li>
#     <li><b> Be on time.</b></li>
#     <li><b> Dress professionally, use soft solid colors.</b></li>
#     <li> Have a neutral background.</li>
#     <li> Have a printed copy of your resume, just in case you need to take a look or something you want to remember during the interview and maybe some notes.</li>
#     <li> Close any unnecessary web browser tabs and apps.</li>
#     <li><b> Place your phone in silent mode, don't be distracted and show respect.</b></li>
#     <li><b> Be calm.</b></li>
#     <li> Keep eye contact (look directly at the camera).</li>
#     <li> Don't excuse yourself on not having used the tool before!</li>
#     <li> Nod to show you are engaged while you are actively listening.</li>
#     <li><b> Don't interrupt your interviewer.</b></li>
#     <li> Speak clearly and confidently. Try to sem calm during the interview.</li>
#     <li> When appropiate use hand gestures and smile.</li>
#     <li> If it's a phone interview, work on your tone of voice.</li>
#     <li><b> Remember to thank the interviewer for his or her time.</b></li>
# </ul>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1><b>What should i consider in an online or phone interview?</b></h1>
# </div>
#
# ### Advantages:
# > - **More personal contact.**
# > - **You can expand your answers freely.**
# > - **You might get the opportunity to see the ofices and get an idea of the work envirorment.**
#
#
# ### Disadvantages:
# > - **You need more time and money.**
# >> A couple of days before, measure how much time it takes you to get to that venue, so that you are on time or a little early.
# > - **You have to think more about your language and facial expressions.****
# > - **If you are introvert, you might not feel as comfortable as in an online or phone interview.**

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2  style="text-align:center"><b>Tips.</b></h2>
# </div>
# <ul style style="line-height: 200%">
#     <li>Make sure you have the address and the name of your interviewer.</li>
#     <li>Take a printed copy of your resume.</li>
#     <li>Arrive early. <b>(at least 10 minutes before)</b>
#     <li>Dress professionally.</li>
#     <li>Shake hands <b>firmly</b>.</li>
#     <li>Avoid looking around the room.</li>
#     <li>Sit upright and show interest.</li>
#     <li>Listen actively.</li>
#     <li>Make eye contact.</li>
#     <li>Smile when appropiate.</li>
#     <li>Speak clearly and confident.</li>
#     <li>Answer what you are asked, do not stray away from the question.</li>
#     <li>Don't interrupt your interviewer.</li>
#     <li>Be genuine.</li>
#     <li>Be polite.</li>
#     <li>Remember to thank the interviewer.</li>
# </ul>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1><b>What should i consider in a technical interview?</b></h1>
# </div>
#
#
# ### It's going to be any kind of interview where you're asked to demonstrate your technical knowledge or expertise.
#
# <ul>
#     <p style style="line-height: 200%">
#     <li>It might be a classic whiteboard interview where you're given a coding problem that you need to solve in front of a manager.</li>
#     <li>Or it can be a take home project, that you're presenting and walking through your process.</li>
#     <li>Sometimes you'll be asked to present a past project and walk through code that you've worked on before.</li>
#     </p>
# </ul>
#
# <h3 style style="line-height: 150%; text-align:justify">
#     But, always it's going to be something where you're having to demonstrate specific technical skills to someone who is close to the actual work, like an engineering manager, members of the technical team, rather than someone from HR.
# </h3>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3 style="text-align:center"><b>Differences between technical interview vs. regular interview.</b></h3>
# </div>
# <h3 style="text-align:center"> It's going to be super specific.</h3>
#
# You need to prove to the company, to the engineering manager and the team you are going to be working with, that you have the technical skills and that you also have the comunication skills to work with a team.
#
# It is as much as you have to demonstrate that you understand specific things about code, as that you can talk to other engineers, other stakeholders like designers, and create a finished project from the information that you're given.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3 style="text-align:center"><b>Most challenging aspects.</b></h3>
# </div>
#
# > **To stay calm and cool, and then communicate effectively and consistently.**
#
# Those are the most relevant tools in an interview, as well as your knowledge.
# Most of engineers has failed a technical interview at least once.
# <br>
#
# <div class="alert alert-block alert-info">
#     <h3 style="text-align:center">Tips and tricks.</h3>
# </div>
#
# - If you're confused, **just tell** the interviewer that you're confused.
# - You can find sample questions for specific companies
# > I recommend practicing them by making a video of yourself solving it and speaking aloud.
# - Practice pair coding with a friend.
# > It's a safe place to get confortable with speaking aloud when you're coding and get practiced with collaborating.
# <br>
# <h3 style style="text-align:justify; line-height=150%">When you finish a project, take a time to write about what you did, it might be a blogpost or as a profile for your portfolio, and talk about exactly the processes that you went through so you're used to putting that coding/engineering experiencie into plain lenguage that's is easy to understand.</h3>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1 style style="text-align:center">Common interview question and How to answer them.</h1>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2 style style="text-align:center">Vocabulary.</h2>
# </div>
#
# <b>Competencies:</b> the abilities to perform a task efficiently. Competencies involve skills, abilities and knowledge. They are your qualifications for a job.
#
# <b>Hard Skills:</b> learned abilities that are acquired and enhanced through practice, repetition, and education. They are teachable and measurable technical abilities that fit the job position.
#
# <b>Soft Skills:</b> they are non-technical skills that relate to how you work and which are not related to a specific job.
#
# <b>Plain language:</b> Clear and effective communication with straightforward expression or using only as many words as are necessary.
#
# <b>Pair Coding or Programming:</b> an Agile technique originating from extreme programming in which two developers get together and code using the same screen.
#
# <b>Portfolio:</b> a portable showcase of your work and talents which represent your skills and achievements.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center"><b>Tell me about yourself.</b></h1>
# </div>
#
# ### It's common that the interviewer might start with the question:
# > ### _Tell me about yourself._
#
# ### And you should have prepared your professional pitch.
#
#
# <div class="alert alert-block alert-info">
#     <h3 style style="text-align:center">Your professional pitch.</h3>
# </div>
#
#
# ### It's a brief summary of the best things about you, your better skills an qualifications.
# ### It should answer:
# <ul>
#     <li>Who you are</li>
#     <li>What you do</li>
#     <li>What makes you unique</li>
#     <li>What you have done</li>
#     <li>What you are looking for</li>
# </ul>
#
# Example:
#
# > - I'm a **(Profesional role)**<br>
# > - Some of my strengths are **(Mention strengths that are aligned with the role)**
# >> - attention to detail
# >> - teamwork
# >> - communication skills
#
# > - I studied **(Specialized knowledge & education)**<br>
# > - I recently worked as a **(Position and company)**<br>
# > - Where I **(list of duties, obligations or responsabilities)**<br>
# > - Now I am looking for **(Goal)**<br>
# > - A new challenge in which I can apply my experience and my qualifications
# <br>
#
# ### You can find another example in: [Tell me about yourself - Example](https://drive.google.com/file/d/1KPfSQcuxS8dqvVYdPh-96uWBPVF2_xDM/view?usp=sharing)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center"><b>Tell me about your past work experiences.</b></h1>
# </div>
#
# ### You need to be positive about what you say about those experiences.
#
# <div class="alert alert-block alert-info">
#     <h3 style="text-align:center">Tips.</h3>
# </div>
#
# <ul>
#     <li>Review the experience you included in your resume.</li>
#     <li>Share what you learned in each role and how it relates to the position you are applying for.</li>
#     <li><b>Be positive</b>, if you are asked why you left previous experiences <b>never give a negative reason.</b></li>
#     <li><b>Don't give any negative comments about your co-workers, employer or the job you are doing.</b></li>
# </ul>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center"><b>Why do you want to work for this company and why shoul we hire you?</b></h1>
# </div>
#
# <div class="alert alert-block alert-info">
#     <h3 style="text-align:center">Tips to know how to answer.</h3>
# </div>
# <ul>
#     <li>Research the company.</li>
#     <li>Include your skills and competencies that you know the company values.</li>
#     <li>Identify what the company needs and why they're looking for a person for this position.</li>
#     <li>Mention what you like about the company and why you would be a good fit for the role.</li>
#     <li>Focus on the value you will bring to your company with your skills, experience and achivements.</li>
#     <li>Give examples on how you achieved goals.</li>
# </ul>
#
# ### Example:
#
# ## Why do you want to work for this company? Why should we hire you?
# > ### I admire your company's results in the industry an I have experience in the services your company provides.
# > ### I'm goal-oriented and I deliver exceptional results, such as improving sales by 80%, and implementing a strategy to lower costs while maintaining quality.
# > ### Since I have worked with people from different countries I adapt easly and work well with other people.
# > ### I am sure I would be a good match for this position. I am interested in international sales and i'm commited to creating innovative strategies to achieve company goals.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center"><b>Talking about your skills and competencies.</b></h1>
# </div>
#
# <ul>
#     <li><h3>What makes you unique?</h3></li>
#     <li><h3>What are those skills and competencies that will bring value to the company?</h3></li>
# </ul>
#
# <div class="alert alert-block alert-info">
#     <h3 style style="text-align:center">Skills vs Competencies.</h3>
#     <h3 style style="text-align:center">Know the difference.</h3>
# </div>
#
# > - Competencies are much broader than skills.
# > - Skills are specific to a task. A skill is the ability to solve problems and perform tasks.
# > - Competencies involve skills, abilities and knowledge. They are your qualifications for a job.
#
# <table style="width:100%">
#     <tr>
#         <th style="text-align:center">Skills</th>
#         <th style="text-align:center">Competencies</th>
#     </tr>
#     <tr>
#         <td>Adaptability</td>
#         <td>Commercial awareness</td>
#     </tr>
#     <tr>
#         <td>Attention to detail</td>
#         <td>Creative thinking</td>
#     </tr>
#     <tr>
#         <td>Problem solving skills</td>
#         <td>Critical thinking</td>
#     </tr>
#     <tr>
#         <td>Teamwork</td>
#         <td>Decision making</td>
#     </tr>
#     <tr>
#         <td>Work ethics</td>
#         <td>Focus</td>
#     </tr>
#     <tr>
#         <td>-------------------------</td>
#         <td>Leadership</td>
#     </tr>
#     <tr>
#         <td>Analytical skills</td>
#         <td>Organization</td>
#     </tr>
#     <tr>
#         <td>Design skills</td>
#         <td>Persuasive Communication</td>
#     </tr>
#     <tr>
#         <td>Presentation skills</td>
#         <td>Responsibility</td>
#     </tr>
#     <tr>
#         <td>Language skills</td>
#         <td>Results orientation</td>
#     </tr>
#     <tr>
#         <td>Technical Skills</td>
#         <td></td>
#     </tr>
# </table>
#
# <br>
#
# <div class="alert alert-block alert-info">
#     <h3 style style="text-align:center">Tips.</h3>
# </div>
#
# <ul>
#     <li>Review the job description to see what are those skills and competence that are needed.</li>
#     <li>Include the ones that are relevant to the job.</li>
#     <li>Use the <b>STAR method</b>:
#         <ul>
#             <li>S ituation</li>
#             <li>T ask</li>
#             <li>A ction</li>
#             <li>R esult</li>
#         </ul>
#     You can talk about your skills and how you apply them.</li>
#     <li>Keep your answers clear and concise.</li>
#     <li>Demonstrate who you will benefit the company</li>
# </ul>
#
# ### You can check an [Example of talking about your skills and competencies](https://drive.google.com/file/d/1I43Ccr-14BNdzPCyVa7kjZBi4K-TGIT5/view?usp=sharing)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center">What are your strengths and weaknesses?</h1>
# </div>
#
# ### To answer this questions:
# > - Be prepared
# > - Be brief
# > - Be honest
# > - Give an example
#
# ### When talking about your strengths, focus on the role you are applying for; don't do this when talking about your weaknesses
#
# ### Mention a weakness you had an how you improved or a weakness you are working on.
#
# <table style="width:100%">
#     <tr>
#         <th style="text-align:center" colspan="2"><h3>EXAMPLES</h3></th>
#     <tr>
#         <th style="text-align:center">STRENGHTS</th>
#         <th style="text-align:center">WEAKNESSES</th>
#     </tr>
#     <tr>
#         <td>Collaborative</td>
#         <td>Do not ask enough questions</td>
#     </tr>
#     <tr>
#         <td>Detail-oriented</td>
#         <td>It has been difficult for me to ask for help</td>
#     </tr>
#     <tr>
#         <td>Disciplined</td>
#         <td>I can be impulsive</td>
#     </tr>
#     <tr>
#         <td>Driven</td>
#         <td>I try to please everyone</td>
#     </tr>
#     <tr>
#         <td>Empathetic</td>
#         <td>I have a tendency of being competitive</td>
#     </tr>
#     <tr>
#         <td>Flexible</td>
#         <td>I am an introvert</td>
#     </tr>
#     <tr>
#         <td>Innovative</td>
#         <td>Limited experience in a skill that is not relevant to the role</td>
#     </tr>
#     <tr>
#         <td>Organized</td>
#         <td>Take on too much responsibility and not skilled at delegating</td>
#     </tr>
#     <tr>
#         <td>Respectful</td>
#         <td>To self-critical</td>
#     </tr>
#     <tr>
#         <td>Trustworthy and Reliable</td>
#         <td>Shy when speaking in public</td>
#     </tr>
# </table>
#
# > ### [Example of how to answer to strengths and weaknesses questions.](https://drive.google.com/file/d/1JNwDkrqEj0Vpml2aev0hQrkWWRfTG7Wa/view?usp=sharing)
#
# ----

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1 style style="text-align:center">Challenging interview question and how to answer them.</h1>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2 style style="text-align:center">Vocabulary.</h2>
# </div>
#
# <b>Behavioral questions:</b> questions that have to do with how you handled past work situations.
#
# <b>Call someone out:</b> an expression which has to do with telling someone about something they did or said and asking them for an explanation.
#
# <b>Job setting / Work setting:</b> your work environment, the place where you work.
#
# <b>Role play:</b> A dramatization in which you perform or act out the part of a person or character in a situation in order to make the topic more clear.
#
# <b>Situational questions:</b> questions about hypothetical work situations. They allow the interviewer to know how you would act if they happened.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center">The salary expectation question.</h1>
# </div>
#
# ## It's a common question: 'What are your salary expectations?'
#
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">Tips.</h2>
# </div>
#
# > ### - Don't ask about the salary before you're asked about it
# > ### - You could divert the question by saying you need more information about the role requirements and expectations.
# > ### - Be aware of your market value and cost of living
# > ### - Be ready to specify your required salary range and explain why
# > ### - Be prepared to negotiate
# > ### - You could say you are open to negotiating depending on the benefits, commissions or bonuses.
#
# ### You should consider your current salary as a base and add a percentage, maybe 15 to 20-25%, depending on the role.
#
# ### Once you've talked about the requirements, prepare the script of your answer to this question:
#
# > ## - Where do you see yourself in 5 years?
#
#
# ### [Examples of answers to salary expectation](https://drive.google.com/file/d/1u7qqsBb35ZdreB9F13875OSh84TncIvc/view?usp=sharing)
#
# ### Some tools:
# > - [Indeed - Salaries](https://www.indeed.com/salaries)
# > - [Salary](https://www.salary.com/)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center">Where do you see yourself in 5 years?</h1>
# </div>
#
# ### When asking about your goals, the employer wants to know if they are aligned to your career path in this position and if they can fulfill your needs and if you want to stay in the company.
#
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">Tips.</h2>
# </div>
#
#
# > - Think in your long term goals and your career path
# > - Show confidence and a positive attitude
# > - Demonstrate how the role will help you reach your goals.
# > - Talk about mentoring as well as training and development opportunities you would like to have
# > - Show enthusiasm and passion about the possible projects that you could do in the company.
#
# Also, you might be prepared to answer **Where do you see yourself in 10 years?** instead of 5
#
# [Example Where do you see yourself in 5 years?](https://drive.google.com/file/d/1yKdCPifULCb_wSDwT6_aRfsCuqLqZyDo/view?usp=sharing)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 style style="text-align:center">Answering situational questions.</h1>
# </div>
#
# ### Question about a hypotetical situation:
# > - **How you would face a problem**
# > - **What you would do to solve it**
# > - **How this solution will benefit the company**
#
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">Tips.</h2>
# </div>
#
# > - Consider the skills required for the role and how you would use those skills to solve a problem.
# > - When talking about the benefits for the company with your solution, consider what are the needs and goals of the company.
#
# Examples:
#
# What would you do if you had to collaborate with a co-worker that is difficult to work with?
# - Well, that might have happened to everyone, we all have different personalities, we don't need to be best friends with everybody. I would sit down with the person and engage in some small talk just so that they know i am invested in them and i'm interested in getting to know them more.
# Establish goals that we could both reach and we could work based on those goals.
#
# What would you do if you made a big mistake but no one noticed? Would you address the mistake even if it would slow down things or would you ignore it and not say anything?
# - It might be easy to want to think that we can ignore this problem and it will go away, but I always value honesty and transparency in a job, so I would definitely speak up and talk about the mistake I made. I know that nobody expects robots in a work setting, so it's okay to make mistakes as long as you ask enough questions and give enough solutions to fix it.
#
# What would you do if you were asked to complete a task that you had never done before?
# - I definitely be up for the challenge, i really like challenging myself and getting out of my comfort zone. So I would ask questions, do an in-depth research and then I would take up the challenge of doing something completely new, I could learn a lot.
#
# If you knew that your boss was completely wrong about something, what would you do?
# - It's OK to have different opinion than your boss, but I would definitely not call him out in front of everybody, even if it's another co-worker. It's important to stablish one on one connections, and so I would ask my boss for a one on one if I think the problem is important enough to talk about and then i would try to reach a middle ground with my boss.
#
# What would you do if you were a manager and one of your team members was not reaching goals and expectations?
# - I would reach out to the person first, instead of just going up to them and scolding them for something that I don't know, I really like investigating what's going on. First I will ask them how they're doing and then I will sit down with them, see if the problem is something personal or if the problem is because the task are unclear, and maybe see goal by goal where it is that they're struggling and what can I do as a supervisor to make their job easier and more understandable
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h1 style style="text-align:center">Challenging interview question and how to answer them.</h1>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h2 style style="text-align:center">Vocabulary.</h2>
# </div>
#
# <b>Being late:</b> Not being on time for a scheduled meeting or event.
#
# <b>Follow up:</b> to investigate closely in order to have a status or more information as a response to something.
#
# <b>If applicable:</b> It expresses that you should consider if something has to do with you, if it is relevant or if it applies.
#
# <b>Mistake:</b> an act or judgment that is not right; something that you are wrong about.
#
# <b>Role:</b> a purpose or position that a person has in a company, a situation, society, or in a relationship; it is related to a duty or obligation that the person has.
#
# <b>Write down:</b> to record something in written form in a piece of paper.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">Questions for the interviewer.</h2>
# </div>
#
# ### It is very important that you ask some questions to your interviewer as well.
#
# ### Why is it important?
# ### It shows:
# > - That you have been actively listening during the interview
# > - You're interested in the company
# > - And that you have done some research
#
# ---
#
# ## Examples of questions that you could ask:
# <ol>
#     <h3><li>How would you describe the company culture?</li></h3>
#     <b>This is very important for us to be comfortable in that role and in the company.</b>
#     <h3><li>What do you like the most about working here?</li></h3>
#     <b>Also has to do with culture and how the envirorment is in the company.</b>
#     <h3><li>How do you define and measure success for this role?</li></h3>
#     <b>It's good to know what will be expected from you.</b>
#     <h3><li>What are the three most important things that you would like me to accomplish in the first six months if I were hired?</li></h3>
#     <h3><li>What do you think is the most challenging aspect of this position?</li></h3>
#     <h3><li>Will I have the opportunity to meet the team during the interview process?</li></h3>
#     <b>You might want to get to know the team before and shows that you like talking to people and that you're a team player.</b>
#     <h3><li>Are there opportunities for professional growth?</li></h3>
#     <h3><li>What do you consider are the main qualities of the people who work here?</li></h3>
#     <h3><li>Do you provide training for employees?</li></h3>
# </ol>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">How to close the job interview effectively and what to do after the interview.</h2>
# </div>
#
# <div class="alert alert-block alert-warning">
#     <h3 style style="text-align:center">Make sure:</h3>
# </div>
#
# - ### All questions were answered.
# > **That the interviewer covered all questions that he or she wanted to ask and also that you have made the questions you wanted to make.**
#
# - ### State your interest and why you are the right person for the job.
#
# - ### Ask for the next steps and how you should follow up on the interview.
#
# - ### You get the contact information you need to follow up after the interview.
#
# - ### Close the inteview on a positive note and thank the inteviewer for the time.
#
# ---
#
# <div class="alert alert-block alert-warning">
#     <h3 style style="text-align:center">After the inteview:</h3>
# </div>
#
# - ### Analyze your answers and how you felt
#
# - ### Write down things you want to remembre from the interview
#
# - ### Contact the references you provided (if applicable).
#
# - ### Connect with your interviewer. Send an email thanking for the interview.
#
# - ### Follow up on the process. This shows that you are very interested in the position.
#
# - ### Be prepared to wait, be patient.
#
# - ### Don't stop the job search until you have an offer.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 style style="text-align:center">Common mistakes.</h2>
# </div>
#
# ### What do yo do with mistakes?
# > **You learn from them.**
#
# ### - Being late for the interview.
# > Be at least 10 minutes before if it's a face to face interview.
# ### - Lying.
# > Not even in your interview or in your resume.
# ### - Not being prepared.
# > Not having done your research
# > Not knowing anything about the company or the role
# ### - Having your cell phone with notifications on.
# ### - Not making any eye contact.
# ### - Bad posture
# > Can reflect that you are not interested in the position
# ### - Not dressing appropriately.
# ### - Not asking questions.
# ### - Asking about holidays or bonuses at the initial interview.
# ### - Saying you've applied to a lot of jobs.
# > I will seem like you're not that interested.
# ### - Making negative comments.
# > - Current job
# > - Employer
# > - Colleagues
# ### - Not following up after an interview.
